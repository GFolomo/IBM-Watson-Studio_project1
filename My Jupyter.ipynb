# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Gires**
# <br>*Machine Learning Engineer*

# %% [markdown]
# I am interested in data science because I want to become a Machine Learning Engineer.

# %% [markdown]
# ### This codes generates a random float number with 2 decimal places.

# %%
import random

# Random float number with 2 decimal places
print(round(random.random(), 2))
# Out:
# 0.71

# %% [markdown]
# 1. Python
# 2. SQL
# 3. R
#
# https://youtube.com
#
#
# <strike>No Power BI in this course</strike>
